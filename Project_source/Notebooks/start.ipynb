# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('cheating_detection_dataset_3.csv')
df
df = df.drop(columns = ['participant_id','competition_id'])
df
# Out:
#       total_submissions  active_days  submissions_per_day  \
# 0                    22           10             2.200000
# 1                    10            7             1.428571
# 2                    17            8             2.125000
# 3                    16            8             2.000000
# 4                    33            8             4.125000
# ...                 ...          ...                  ...
# 4980                 29           10             2.900000
# 4981                 22            7             3.142857
# 4982                  6            2             3.000000
# 4983                 29           10             2.900000
# 4984                  7            1             7.000000
#
#       submission_avg_initial_days  avg_submissions_mid  submissions_end  \
# 0                        2.333333             3.000000                2
# 1                        1.000000             0.666667                0
# 2                        2.333333             1.000000                0
# 3                        1.333333             1.333333                4
# 4                        2.000000             3.666667                4
# ...                           ...                  ...              ...
# 4980                     3.333333             3.000000                3
# 4981                     0.333333             2.333333                3
# 4982                     0.000000             0.000000                0
# 4983                     2.666667             3.000000                3
# 4984                     0.000000             0.000000                7
#
#       median_score  top_score  lowest_score  gap_median_top  ...  \
# 0         1.422391   0.643473      2.495192        0.778918  ...
# 1         1.440718   0.571049      2.388279        0.869669  ...
# 2         1.522378   0.585548      2.416366        0.936830  ...
# 3         1.358629   0.619937      2.384342        0.738692  ...
# 4         1.331861   0.551352      2.433730        0.780509  ...
# ...            ...        ...           ...             ...  ...
# 4980      0.515016   0.426558      1.426867        0.088458  ...
# 4981      0.736494   0.402516      2.439918        0.333978  ...
# 4982      0.530714   0.484453      0.575788        0.046261  ...
# 4983      0.518362   0.425564      1.397866        0.092799  ...
# 4984      0.472861   0.417872      0.565920        0.054988  ...
#
#       user_min_score_diff  above_below_claude_min  score_time_corr  \
# 0               -0.017763                       1        -0.764667
# 1               -0.090187                       1        -0.974284
# 2               -0.075688                       1        -0.976484
# 3               -0.041299                       1        -0.784678
# 4               -0.109884                       1        -0.786184
# ...                   ...                     ...              ...
# 4980            -0.148753                       1        -0.793446
# 4981            -0.172796                       1        -0.765788
# 4982            -0.090858                       1        -0.821397
# 4983            -0.149748                       1        -0.749721
# 4984            -0.157439                       1        -0.921073
#
#       time_to_best_score_hours  quiz_participation  final_rank  \
# 0                   217.227229                   9          16
# 1                   193.250851                   6          12
# 2                   181.698905                   6          13
# 3                   202.161856                   6          14
# 4                   204.774922                   8          10
# ...                        ...                 ...         ...
# 4980                117.036404                   9           6
# 4981                167.503564                   8           2
# 4982                 21.406459                   3          11
# 4983                 99.648716                  10           4
# 4984                  1.741780                   1           3
#
#       rank_to_submissions  rank_to_quiz_participation  description_rate  \
# 0                0.727273                    1.600000             0.909
# 1                1.200000                    1.714286             0.700
# 2                0.764706                    1.857143             0.824
# 3                0.875000                    2.000000             0.812
# 4                0.303030                    1.111111             0.939
# ...                   ...                         ...               ...
# 4980             0.206897                    0.600000             0.793
# 4981             0.090909                    0.222222             0.818
# 4982             1.833333                    2.750000             0.833
# 4983             0.137931                    0.363636             0.862
# 4984             0.428571                    1.500000             0.286
#
#       cheated
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# ...       ...
# 4980        0
# 4981        0
# 4982        1
# 4983        0
# 4984        1
#
# [4985 rows x 26 columns]

# %%
df.describe()
# Out:
#        total_submissions  active_days  submissions_per_day  \
# count        4985.000000  4985.000000          4985.000000
# mean           20.311535     6.586961             3.149178
# std            12.796258     3.052922             1.340330
# min             2.000000     1.000000             1.000000
# 25%             9.000000     5.000000             2.200000
# 50%            19.000000     8.000000             3.000000
# 75%            30.000000     9.000000             3.750000
# max            74.000000    10.000000             8.000000
#
#        submission_avg_initial_days  avg_submissions_mid  submissions_end  \
# count                  4985.000000          4985.000000      4985.000000
# mean                      1.460983             1.971648         2.750853
# std                       1.110089             1.621031         2.509875
# min                       0.000000             0.000000         0.000000
# 25%                       0.666667             0.666667         0.000000
# 50%                       1.333333             1.666667         2.000000
# 75%                       2.333333             3.000000         4.000000
# max                       6.000000             9.333333        10.000000
#
#        median_score    top_score  lowest_score  gap_median_top  ...  \
# count   4985.000000  4985.000000   4985.000000     4985.000000  ...
# mean       1.056498     0.595503      1.846386        0.460995  ...
# std        0.423371     0.257889      0.666368        0.360551  ...
# min        0.402018     0.300000      0.488215        0.000376  ...
# 25%        0.601941     0.446435      1.259200        0.096833  ...
# 50%        1.068257     0.515976      2.213866        0.384490  ...
# 75%        1.439786     0.652220      2.371116        0.796369  ...
# max        2.243555     2.004726      2.600000        1.788525  ...
#
#        user_min_score_diff  above_below_claude_min  score_time_corr  \
# count          4985.000000             4985.000000      4985.000000
# mean              0.005462                0.651354        -0.762285
# std               0.260828                0.476589         0.305539
# min              -0.340143                0.000000        -1.000000
# 25%              -0.144206                0.000000        -0.963970
# 50%              -0.066068                1.000000        -0.813836
# 75%               0.066424                1.000000        -0.700529
# max               1.413622                1.000000         1.000000
#
#        time_to_best_score_hours  quiz_participation   final_rank  \
# count               4985.000000         4985.000000  4985.000000
# mean                 149.888709            5.868205    17.234102
# std                   79.572347            2.717667    10.770775
# min                    0.000000            0.000000     1.000000
# 25%                  117.151148            4.000000     8.000000
# 50%                  185.061568            6.000000    16.000000
# 75%                  207.925612            8.000000    25.000000
# max                  239.534772           10.000000    46.000000
#
#        rank_to_submissions  rank_to_quiz_participation  description_rate  \
# count          4985.000000                 4985.000000       4985.000000
# mean              1.747510                    3.466488          0.773546
# std               2.616925                    3.819233          0.200980
# min               0.013514                    0.090909          0.000000
# 25%               0.400000                    1.222222          0.667000
# 50%               0.896552                    2.454545          0.838000
# 75%               1.869565                    4.250000          0.912000
# max              22.500000                   45.000000          1.000000
#
#            cheated
# count  4985.000000
# mean      0.266800
# std       0.442332
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 26 columns]

# %%
df

X = df.drop(columns = ['cheated'])
y = df['cheated']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, shuffle =True)

# train_df = df.copy()
# df_0 = train_df[train_df['Diabetes_binary'] == 0]
# df_1 = train_df[train_df['Diabetes_binary'] == 1]

# df_1 = df_1.sample(len(df_0), replace = True, random_state = 42)

# train_df = pd.concat([df_0, df_1])
# train_df = train_df.sample(frac= 1, random_state = 42)
# # train_df['row_id'] = train_df.index
# # train_df.to_csv('train_NN_0p6.csv', index = False)
# # train_df = train_df.drop(columns = ['row_id'])

# X_train = train_df.drop('Diabetes_binary', axis=1)
# y_train = train_df['Diabetes_binary']
# y_train = pd.get_dummies(y_train, dtype = int).values

# %%
# display(X_train)
# y_train = pd.DataFrame({
#     'cheated' : y_train
# })
# train_df = pd.concat([X_train, y_train], axis = 1)
# df_0 = train_df[train_df['cheated'] == 0]
# df_1 = train_df[train_df['cheated'] == 1]

# df_1 = df_1.sample(len(df_0), replace = True, random_state = 42)

# train_df = pd.concat([df_0, df_1])
# train_df = train_df.sample(frac= 1, random_state = 42)


# X_train = train_df.drop('cheated', axis=1)
# y_train = train_df['cheated']
# y_train = pd.get_dummies(y_train, dtype = int).values
# Out:
#       total_submissions  active_days  submissions_per_day  \
# 699                  21            8             2.625000
# 2031                 15            8             1.875000
# 2237                  6            2             3.000000
# 3175                 32           10             3.200000
# 647                  35            9             3.888889
# ...                 ...          ...                  ...
# 2143                 16            5             3.200000
# 1863                 32           10             3.200000
# 871                  29           10             2.900000
# 901                  34            7             4.857143
# 1632                 32            8             4.000000
#
#       submission_avg_initial_days  avg_submissions_mid  submissions_end  \
# 699                      2.333333             1.333333                5
# 2031                     2.666667             1.333333                1
# 2237                     0.000000             0.000000                0
# 3175                     2.666667             3.333333                3
# 647                      1.666667             2.666667                4
# ...                           ...                  ...              ...
# 2143                     2.000000             1.000000                7
# 1863                     3.000000             3.666667                3
# 871                      3.000000             3.000000                4
# 901                      0.666667             1.666667                7
# 1632                     1.333333             2.666667                4
#
#       median_score  top_score  lowest_score  gap_median_top  ...  \
# 699       1.453923   0.563971      2.270877        0.889952  ...
# 2031      1.480711   0.741393      2.136678        0.739318  ...
# 2237      0.549681   0.532595      0.564345        0.017086  ...
# 3175      0.473941   0.402165      0.942838        0.071777  ...
# 647       1.331843   0.497104      2.459914        0.834738  ...
# ...            ...        ...           ...             ...  ...
# 2143      1.339551   0.451351      2.035658        0.888200  ...
# 1863      0.527565   0.459540      1.304054        0.068025  ...
# 871       0.509088   0.429109      0.987346        0.079979  ...
# 901       1.234619   0.663957      2.235217        0.570663  ...
# 1632      0.737451   0.535955      2.288528        0.201496  ...
#
#       claude_min_score  user_min_score_diff  above_below_claude_min  \
# 699           0.599101            -0.035130                       1
# 2031          0.615836             0.125557                       0
# 2237          0.585995            -0.053400                       1
# 3175          0.610832            -0.208667                       1
# 647           0.567775            -0.070671                       1
# ...                ...                  ...                     ...
# 2143          0.590131            -0.138780                       1
# 1863          0.681016            -0.221476                       1
# 871           0.620128            -0.191019                       1
# 901           0.586526             0.077430                       0
# 1632          0.567986            -0.032031                       1
#
#       score_time_corr  time_to_best_score_hours  quiz_participation  \
# 699         -0.985484                222.072056                   6
# 2031        -0.946949                232.000652                   3
# 2237         0.167242                 16.130816                   0
# 3175        -0.797747                199.447084                  10
# 647         -0.829335                156.882957                   8
# ...               ...                       ...                 ...
# 2143        -0.980815                225.743497                   3
# 1863        -0.813356                197.639853                   6
# 871         -0.754084                128.699962                   9
# 901         -0.373017                170.235009                   9
# 1632        -0.828387                178.587345                   4
#
#       final_rank  rank_to_submissions  rank_to_quiz_participation  \
# 699           29             1.380952                    4.142857
# 2031          27             1.800000                    6.750000
# 2237          24             4.000000                   24.000000
# 3175           4             0.125000                    0.363636
# 647            8             0.228571                    0.888889
# ...          ...                  ...                         ...
# 2143           3             0.187500                    0.750000
# 1863           7             0.218750                    1.000000
# 871           10             0.344828                    1.000000
# 901           17             0.500000                    1.700000
# 1632          20             0.625000                    4.000000
#
#       description_rate
# 699              0.667
# 2031             0.600
# 2237             0.167
# 3175             0.812
# 647              0.886
# ...                ...
# 2143             0.438
# 1863             0.844
# 871              0.793
# 901              0.971
# 1632             0.969
#
# [3988 rows x 25 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vamsi\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 4
#       2 y_train
#       3 train_df = pd.concat([X_train, y_train], axis = 1)
# ----> 4 df_0 = train_df[train_df[''] == 0]
#       5 df_1 = train_df[train_df['Diabetes_binary'] == 1]
#       7 df_1 = df_1.sample(len(df_0), replace = True, random_state = 42)
#
# File c:\Users\vamsi\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\vamsi\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: ''

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\vamsi\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\vamsi\anaconda3\lib\site-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in c:\users\vamsi\anaconda3\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in c:\users\vamsi\anaconda3\lib\site-packages (from optuna) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\vamsi\anaconda3\lib\site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\vamsi\anaconda3\lib\site-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in c:\users\vamsi\anaconda3\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\vamsi\anaconda3\lib\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in c:\users\vamsi\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\vamsi\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in c:\users\vamsi\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: colorama in c:\users\vamsi\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\vamsi\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\vamsi\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\vamsi\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\vamsi\anaconda3\Lib\site-packages)

# %%
import optuna
from sklearn.metrics import f1_score, classification_report
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold

def objective(trial):
    
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 300, 1200),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 30),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        'gamma': trial.suggest_float('gamma', 1e-3, 5.0, log=True),
        'random_state': 42,
        'n_jobs': -1 
    }
    cv = StratifiedKFold(n_splits= 5, shuffle = True, random_state= 42)
    scores = cross_val_score(
        estimator = XGBClassifier(**param),
        X= X_train, y = y_train, cv = cv,
        scoring='f1_macro',
        n_jobs = -1
    )

    return scores.mean()

study = optuna.create_study(direction='maximize', study_name="XGBoost_CV")
study.optimize(objective, n_trials=50, show_progress_bar=True)



print(f"Best CV f1 score: {study.best_value:.4f}")
print("Best Hyperparameters:")
for key, value in study.best_params.items():
    print(f"    '{key}': {value},")
# Out:
# [I 2026-07-23 12:22:46,169] A new study created in memory with name: XGBoost_CV
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-07-23 12:22:54,538] Trial 0 finished with value: 0.9344740672550749 and parameters: {'n_estimators': 1021, 'max_depth': 3, 'learning_rate': 0.020158491584193375, 'subsample': 0.4256691990634186, 'colsample_bytree': 0.8955036831976279, 'min_child_weight': 10, 'reg_alpha': 0.20942311710988076, 'reg_lambda': 0.11646909228453813, 'gamma': 0.0024925424180175203}. Best is trial 0 with value: 0.9344740672550749.
# [I 2026-07-23 12:22:59,633] Trial 1 finished with value: 0.9402155290908661 and parameters: {'n_estimators': 825, 'max_depth': 9, 'learning_rate': 0.02080353176285471, 'subsample': 0.6988773106008164, 'colsample_bytree': 0.711393404176003, 'min_child_weight': 21, 'reg_alpha': 0.8772182989303271, 'reg_lambda': 0.005240831956007284, 'gamma': 1.5712929761392638}. Best is trial 1 with value: 0.9402155290908661.
# [I 2026-07-23 12:23:01,095] Trial 2 finished with value: 0.9324186823485425 and parameters: {'n_estimators': 775, 'max_depth': 5, 'learning_rate': 0.09932035682281762, 'subsample': 0.7575977632260744, 'colsample_bytree': 0.6820865850454938, 'min_child_weight': 6, 'reg_alpha': 4.090029872146402, 'reg_lambda': 0.0011967149989077915, 'gamma': 0.04835450836003664}. Best is trial 1 with value: 0.9402155290908661.
# [I 2026-07-23 12:23
. Best is trial 39 with value: 0.9411846259793972.
# [I 2026-07-23 12:24:16,185] Trial 47 finished with value: 0.9399382315857657 and parameters: {'n_estimators': 1125, 'max_depth': 6, 'learning_rate': 0.010404567457049848, 'subsample': 0.7707320685412061, 'colsample_bytree': 0.4410513761144802, 'min_child_weight': 22, 'reg_alpha': 0.28742303310960404, 'reg_lambda': 0.0020437585157746436, 'gamma': 2.9941037698527153}. Best is trial 39 with value: 0.9411846259793972.
# [I 2026-07-23 12:24:18,150] Trial 48 finished with value: 0.93958568591546 and parameters: {'n_estimators': 1199, 'max_depth': 7, 'learning_rate': 0.007126314132535685, 'subsample': 0.8402087641000193, 'colsample_bytree': 0.474914083130988, 'min_child_weight': 27, 'reg_alpha': 0.0492882968242549, 'reg_lambda': 0.001908702894919158, 'gamma': 1.68846535696503}. Best is trial 39 with value: 0.9411846259793972.
# [I 2026-07-23 12:24:20,090] Trial 49 finished with value: 0.9383692050507311 and parameters: {'n_estimators': 1051, 'max_depth': 5, 'learning_rate': 0.012644288623358717, 'subsample': 0.936302726730041, 'colsample_bytree': 0.7354989378694521, 'min_child_weight': 21, 'reg_alpha': 0.16422385197775197, 'reg_lambda': 0.0034874410617377434, 'gamma': 0.49817041867707085}. Best is trial 39 with value: 0.9411846259793972.
# Best CV f1 score: 0.9412
# Best Hyperparameters:
#     'n_estimators': 966,
#     'max_depth': 5,
#     'learning_rate': 0.014157796791360346,
#     'subsample': 0.7204929548402691,
#     'colsample_bytree': 0.7328961874656676,
#     'min_child_weight': 20,
#     'reg_alpha': 0.915889128018203,
#     'reg_lambda': 1.843426456876356,
#     'gamma': 0.8405303140909929,

# %%
xgb = XGBClassifier(**(study.best_params))
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7328961874656676, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=0.8405303140909929, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.014157796791360346,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=20, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=966, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(X_test)
f1_score = f1_score(y_test,y_pred, average='macro')
display(f1_score)
print(classification_report(y_test, y_pred))
# Out:
# 0.9305970548862115
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       731
#            1       0.96      0.84      0.90       266
#
#     accuracy                           0.95       997
#    macro avg       0.95      0.91      0.93       997
# weighted avg       0.95      0.95      0.95       997

# %%
importance = pd.DataFrame({
    'Feature' : X_train.columns,
    'Importance' : xgb.feature_importances_
})

importance = importance.sort_values(by = 'Importance', ascending= False)
display(importance)
# Out:
#                         Feature  Importance
# 1                   active_days    0.135554
# 8                  lowest_score    0.127057
# 13    peak_submissions_per_hour    0.126284
# 17       above_below_claude_min    0.111028
# 18              score_time_corr    0.102979
# 14       top_score_on_peak_hour    0.087316
# 7                     top_score    0.046152
# 0             total_submissions    0.043171
# 20           quiz_participation    0.034369
# 3   submission_avg_initial_days    0.030835
# 19     time_to_best_score_hours    0.027982
# 9                gap_median_top    0.020571
# 4           avg_submissions_mid    0.019690
# 24             description_rate    0.011667
# 10               gap_lowest_top    0.011245
# 16          user_min_score_diff    0.009641
# 12        top_score_on_peak_day    0.009167
# 6                  median_score    0.008121
# 2           submissions_per_day    0.006768
# 21                   final_rank    0.006018
# 11     peak_submissions_per_day    0.005750
# 5               submissions_end    0.005267
# 23   rank_to_quiz_participation    0.004956
# 22          rank_to_submissions    0.004379
# 15             claude_min_score    0.004031
